# %%
import numpy as np

# %%
arr =  np.array([2,4,6,8])
arr
# Out:
# array([2, 4, 6, 8])

# %%
#  list 
a = [3,5,2,4.4 , "hello"]
a
# Out:
# [3, 5, 2, 4.4, 'hello']

# %%
np.array(a)
# Out:
# array(['3', '5', '2', '4.4', 'hello'], dtype='<U32')

# %%
arr =  np.array([2,4,6,8])
arr
